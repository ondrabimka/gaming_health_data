# %% [markdown]
# # Main exploration notebook

# %%
import plotly.io as pio
pio.renderers.default = "png"

# %%
import pandas as pd
from gaming_health_data.src.utils import DATA_DIR
from gaming_health_data.src.EKGAnalyzer import EKGAnalyzer
from gaming_health_data.src.video_analyzer import VideoAnalyzer
from gaming_health_data.src.mouse_analyzer import MouseAnalyzer
from gaming_health_data.src.keyboard_analyzer import KeyboardAnalyzer

# %%
ekg_df = pd.DataFrame.EKG.from_file(DATA_DIR / 'ekg_data_28_04_2024.txt')
video_df = pd.DataFrame.Video.from_file(DATA_DIR / 'video_annotation')
mouse_df = pd.DataFrame.Mouse.from_file(DATA_DIR / 'mouse_log_28_04_2024.csv')
keyboard_df = pd.DataFrame.Keyboard.from_file(DATA_DIR / 'keyboard_log_28_04_2024.csv')

# %% [markdown]
# #### EKG

# %%
ekg_df[500:1000].EKG.plot_ekg_data()

# %%
ekg_df.EKG.plot_moving_avg_bpm()

# %% [markdown]
# #### Mouse data

# %%
mouse_df.Mouse.plot_clicks_per_second(window_size=2)

# %% [markdown]
# #### Keyborad data

# %%
keyboard_df.Keyboard.plot_clicks_per_second(window_size=4)

# %%
keyboard_df.Keyboard.plot_key_presses_histogram()

# %% [markdown]
# #### Video data

# %%
video_df.Video.plot_timeline()
